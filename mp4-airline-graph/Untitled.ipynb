# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
from my_graph import Digraph
from my_draw_graph import *

with open("data/routes.txt") as f:
    txt = f.read()
    data = txt.split("\n")
        
g = Digraph()
for x in data[1:-1]:
    x = x.split(";")
    if(x[0] == "2B"):
        g.addEdge(x[1], x[2], float("%.2f" % float(x[3])))

        
print("DATA LENGTH:::", len(data))
print("EDGES:::", len(g.edges()))
print("VERTICES:::", len(g.vers()))
# Out:
# DATA LENGTH::: 65264
# EDGES::: 40
# VERTICES::: 16

# %%
with open("data/routes.txt") as f:
    txt = f.read()
    data = txt.split("\n")
        
g = Digraph()
for x in data[1:-1]:
    x = x.split(";")
    if(x[0] == "2B"):
        g.addEdge(x[1], x[2], float("%.2f" % float(x[3])))

# draw_graph_mst(g, "LED")

# %%
draw_graph_mst(Digraph.simple_graph(), "A")

# %%
g = Digraph.simple_graph()
print(g)
# Out:
# A: {A--3--D, A--3--C, A--2--B}
# B: {B--4--C, B--3--E, B--2--A}
# C: {C--1--E, C--3--A, C--6--F, C--4--B, C--5--D}
# D: {D--7--F, D--3--A, D--5--C}
# E: {E--1--C, E--8--F, E--3--B}
# F: {F--8--E, F--9--G, F--6--C, F--7--D}
# G: {G--9--F}
